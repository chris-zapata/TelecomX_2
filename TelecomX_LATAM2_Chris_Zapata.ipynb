# %% [markdown]
# <a href="https://colab.research.google.com/github/chris-zapata/TelecomX_2/blob/main/TelecomX_LATAM2_Chris_Zapata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛠️ **Preparación de los Datos**

# %% [markdown]
# ## **Extracción del Archivo Tratado**

# %% [markdown]
# Carga el archivo CSV que contiene los datos tratados anteriormente.
# 📂 Atención: Utiliza el mismo archivo que limpiaste y organizaste en la Parte 1 del desafío Telecom X. Debe contener solo las columnas relevantes, ya con los datos corregidos y estandarizados.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('datos_tratados.csv')

# %%
df
# Out:
#       CustomerID Churn  Gender SeniorCitizen Partner Dependents  Tenure  \
# 0     0002-ORFBO    No  Female            No     Yes        Yes       9
# 1     0003-MKNFE    No    Male            No      No         No       9
# 2     0004-TLHLJ   Yes    Male            No      No         No       4
# 3     0011-IGKFF   Yes    Male           Yes     Yes         No      13
# 4     0013-EXCHZ   Yes  Female           Yes     Yes         No       3
# ...          ...   ...     ...           ...     ...        ...     ...
# 7038  9987-LUTYD    No  Female            No      No         No      13
# 7039  9992-RRAMN   Yes    Male            No     Yes         No      22
# 7040  9992-UJOEL    No    Male            No      No         No       2
# 7041  9993-LHIEB    No    Male            No     Yes        Yes      67
# 7042  9995-HOTOH    No    Male            No     Yes        Yes      63
#
#      PhoneService MultipleLines InternetService  ... DeviceProtection  \
# ...

# %%
# Conociendo las columnas del DataFrame

df.columns
# Out:
# Index(['CustomerID', 'Churn', 'Gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'Tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'ChargesDaily', 'ChargesMonthly',
#        'ChargesTotal'],
#       dtype='object')

# %%
# Conocer los tipos de datos

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   Gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   object
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   Tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %% [markdown]
# ## **Eliminación de Columnas Irrelevantes**

# %% [markdown]
# Elimina columnas que no aportan valor al análisis o a los modelos predictivos, como identificadores únicos (por ejemplo, el ID del cliente). Estas columnas no ayudan en la predicción de la cancelación y pueden incluso perjudicar el desempeño de los modelos.

# %%
# Eliminación de la columna CustomerID

df = df.drop('CustomerID', axis=1)
df
# Out:
#      Churn  Gender SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0       No  Female            No     Yes        Yes       9          Yes
# 1       No    Male            No      No         No       9          Yes
# 2      Yes    Male            No      No         No       4          Yes
# 3      Yes    Male           Yes     Yes         No      13          Yes
# 4      Yes  Female           Yes     Yes         No       3          Yes
# ...    ...     ...           ...     ...        ...     ...          ...
# 7038    No  Female            No      No         No      13          Yes
# 7039   Yes    Male            No     Yes         No      22          Yes
# 7040    No    Male            No      No         No       2          Yes
# 7041    No    Male            No     Yes        Yes      67          Yes
# 7042    No    Male            No     Yes        Yes      63           No
#
#      MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
# corregir las columnas que cuentan con opción "No internet service". Se pasará a NO
# la razón es que para el modelo no agrega valor esta opción, no así para el challenge 1

cols_to_fix = [
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

for col in cols_to_fix:
    df[col] = df[col].replace({'No internet service': 'No'})

# %%
df[cols_to_fix]
# Out:
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No         Yes         Yes
# 1                No           No               No          No          No
# 2                No           No              Yes          No          No
# 3                No          Yes              Yes          No         Yes
# 4                No           No               No         Yes         Yes
# ...             ...          ...              ...         ...         ...
# 7038            Yes           No               No         Yes          No
# 7039             No           No               No          No          No
# 7040             No          Yes               No          No          No
# 7041            Yes           No              Yes         Yes          No
# 7042            Yes          Yes              Yes          No         Yes
#
#      StreamingMovies
# 0                 No
# 1                Yes
# ...

# %%
# Revisión de valores únicos por columna

for col in df.columns:
  if df[col].nunique() <= 10:
    unique_values = df[col].unique()
    print("-"*50)
    print(f"Valores únicos en la columna '{col}': {unique_values}")
  else:
    print("-"*50)
    print(f"La columna '{col}' tiene {df[col].nunique()} valores únicos")
# Out:
# --------------------------------------------------
# Valores únicos en la columna 'Churn': ['No' 'Yes']
# --------------------------------------------------
# Valores únicos en la columna 'Gender': ['Female' 'Male']
# --------------------------------------------------
# Valores únicos en la columna 'SeniorCitizen': ['No' 'Yes']
# --------------------------------------------------
# Valores únicos en la columna 'Partner': ['Yes' 'No']
# --------------------------------------------------
# Valores únicos en la columna 'Dependents': ['Yes' 'No']
# --------------------------------------------------
# La columna 'Tenure' tiene 73 valores únicos
# --------------------------------------------------
# Valores únicos en la columna 'PhoneService': ['Yes' 'No']
# --------------------------------------------------
# Valores únicos en la columna 'MultipleLines': ['No' 'Yes']
# --------------------------------------------------
# ...

# %%
# Verificación de los valores nulos

df.isnull().sum()
# Out:
# Churn               0
# Gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# Tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# ChargesDaily        0
# ChargesMonthly      0
# ChargesTotal        0
# dtype: int64

# %%
# Verificación de valores vacíos

df.isna().sum()
# Out:
# Churn               0
# Gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# Tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# ChargesDaily        0
# ChargesMonthly      0
# ChargesTotal        0
# dtype: int64

# %%
# Breve exploración de las variables

df.describe()
# Out:
#             Tenure  ChargesDaily  ChargesMonthly  ChargesTotal
# count  7043.000000   7043.000000     7043.000000   7043.000000
# mean     32.371149      2.158675       64.761692   2279.734304
# std      24.559481      1.003088       30.090047   2266.794470
# min       0.000000      0.610000       18.250000      0.000000
# 25%       9.000000      1.180000       35.500000    398.550000
# 50%      29.000000      2.340000       70.350000   1394.550000
# 75%      55.000000      2.990000       89.850000   3786.600000
# max      72.000000      3.960000      118.750000   8684.800000

# %%
# Breve exploración de las variables categóricas

df.describe(include="object")
# Out:
#        Churn Gender SeniorCitizen Partner Dependents PhoneService  \
# count   7043   7043          7043    7043       7043         7043
# unique     2      2             2       2          2            2
# top       No   Male            No      No         No          Yes
# freq    5174   3555          5901    3641       4933         6361
#
#        MultipleLines InternetService OnlineSecurity OnlineBackup  \
# count           7043            7043           7043         7043
# unique             2               3              2            2
# top               No     Fiber optic             No           No
# freq            4072            3096           5024         4614
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  \
# count              7043        7043        7043            7043
# unique                2           2           2               2
# top                  No          No          No              No
# ...

# %%
# Preparación de un df numérico para ver las correlaciones entre variables numéricas

df_numeric = df.select_dtypes(include=["int64", "float64"])

# Dado que CHURN es la variable objetivo del análisis, la pasaremos a numérica para la correlación

df_numeric["Churn"] = df["Churn"].map({"Yes": 1, "No": 0})

# Creamos la matriz de correlación a partir del df numérico

corr_matrix = df_numeric.corr()

# Creamos la visualización tipo heatmap

plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación - Variábles Numericas")
plt.show()

# %%
# Eliminamos las columnas de ChagesDaily y ChargesTotal, dado alto riesgo de multicolinearidad

df = df.drop(columns=["ChargesDaily","ChargesTotal"])
df
# Out:
#      Churn  Gender SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0       No  Female            No     Yes        Yes       9          Yes
# 1       No    Male            No      No         No       9          Yes
# 2      Yes    Male            No      No         No       4          Yes
# 3      Yes    Male           Yes     Yes         No      13          Yes
# 4      Yes  Female           Yes     Yes         No       3          Yes
# ...    ...     ...           ...     ...        ...     ...          ...
# 7038    No  Female            No      No         No      13          Yes
# 7039   Yes    Male            No     Yes         No      22          Yes
# 7040    No    Male            No      No         No       2          Yes
# 7041    No    Male            No     Yes        Yes      67          Yes
# 7042    No    Male            No     Yes        Yes      63           No
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
# Revisión de variables categóricas

categorical_cols = df.select_dtypes(include=["object"]).columns
categorical_cols = categorical_cols.drop("Churn")
categorical_cols
# Out:
# Index(['Gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod'],
#       dtype='object')

# %%
# Revisión de las proporciones e impactos de las variables categóricas en el Churn

for col in categorical_cols:
    print(f"\n📌 Análisis de variable: {col}")

    # Calculamos la tabla cruzada normalizada
    ct = pd.crosstab(df[col], df["Churn"], normalize="index") * 100

    # Aplicamos el formato de 4 decimales y el símbolo %
    display(ct.style.format("{:.4f}%"))
# Out:
# 📌 Análisis de variable: Gender
# <style type="text/css">
# </style>
# <table id="T_21e21" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Churn</th>
#       <th id="T_21e21_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_21e21_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21e21_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_21e21_row0_col0" class="data row0 col0" >73.0791%</td>
#       <td id="T_21e21_row0_col1" class="data row0 col1" >26.9209%</td>
#     </tr>
#     <tr>
#       <th id="T_21e21_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_21e21_row1_col0" class="data row1 col0" >73.8397%</td>
# ...

# %% [markdown]
# Método Chi-Squared para revisión de variables categóricas

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import chi2

# Crea copia
df_rank = df.copy()

# Convertir Churn para binario
df_rank["Churn"] = df_rank["Churn"].map({"Yes": 1, "No": 0})

# Separar variables categóricas
categorical_cols = df_rank.select_dtypes(include=["object"]).columns

# Aplicar Label Encoding temporario
le = LabelEncoder()
for col in categorical_cols:
    df_rank[col] = le.fit_transform(df_rank[col])

# Separar X e y
X_cat = df_rank[categorical_cols]
y = df_rank["Churn"]

# Aplicar teste Qui-cuadrado
chi_scores, p_values = chi2(X_cat, y)

# Criar DataFrame com ranking
chi_df = pd.DataFrame({
    "Variable": categorical_cols,
    "Chi2 Score": chi_scores,
    "p-value": p_values
})

# Ordenar por importancia
chi_df = chi_df.sort_values(by="Chi2 Score", ascending=False)

chi_df
# Out:
#             Variable   Chi2 Score        p-value
# 13          Contract  1115.780167  1.227941e-244
# 7     OnlineSecurity   147.295858   6.761696e-34
# 10       TechSupport   135.559783   2.490549e-31
# 1      SeniorCitizen   134.351545   4.576959e-31
# 3         Dependents   133.036443   8.876729e-31
# 14  PaperlessBilling   105.680863   8.661987e-25
# 2            Partner    82.412083   1.104764e-19
# 15     PaymentMethod    58.492250   2.040933e-14
# 8       OnlineBackup    31.217694   2.306541e-08
# 9   DeviceProtection    20.226662   6.878750e-06
# 11       StreamingTV    17.334235   3.134881e-05
# 12   StreamingMovies    16.242531   5.572887e-05
# 6    InternetService     9.821028   1.725279e-03
# 5      MultipleLines     6.548512   1.049719e-02
# 0             Gender     0.258699   6.110156e-01
# 4       PhoneService     0.097261   7.551421e-01

# %%
# Se deben eliminar todas las variables categóricas cuyo p-value sea menor a 0.05

significant_vars = chi_df[chi_df["p-value"] < 0.05]

print("\n✅ Variables significativas (p < 0.05):")
display(significant_vars)
# Out:
# ✅ Variables significativas (p < 0.05):
#             Variable   Chi2 Score        p-value
# 13          Contract  1115.780167  1.227941e-244
# 7     OnlineSecurity   147.295858   6.761696e-34
# 10       TechSupport   135.559783   2.490549e-31
# 1      SeniorCitizen   134.351545   4.576959e-31
# 3         Dependents   133.036443   8.876729e-31
# 14  PaperlessBilling   105.680863   8.661987e-25
# 2            Partner    82.412083   1.104764e-19
# 15     PaymentMethod    58.492250   2.040933e-14
# 8       OnlineBackup    31.217694   2.306541e-08
# 9   DeviceProtection    20.226662   6.878750e-06
# 11       StreamingTV    17.334235   3.134881e-05
# 12   StreamingMovies    16.242531   5.572887e-05
# 6    InternetService     9.821028   1.725279e-03
# 5      MultipleLines     6.548512   1.049719e-02

# %%
# Con el análisis anterior, solamente 2 variables categóricas serán eliminadas
# Estas variables son: "Gender" y "PhoneService"

df = df.drop(columns=["Gender", "PhoneService"])
df
# Out:
#      Churn SeniorCitizen Partner Dependents  Tenure MultipleLines  \
# 0       No            No     Yes        Yes       9            No
# 1       No            No      No         No       9           Yes
# 2      Yes            No      No         No       4            No
# 3      Yes           Yes     Yes         No      13            No
# 4      Yes           Yes     Yes         No       3            No
# ...    ...           ...     ...        ...     ...           ...
# 7038    No            No      No         No      13            No
# 7039   Yes            No     Yes         No      22           Yes
# 7040    No            No      No         No       2            No
# 7041    No            No     Yes        Yes      67            No
# 7042    No            No     Yes        Yes      63            No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# ...

# %% [markdown]
# Preparación de los set de datos para los modelos de ML

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %%
# Preparamos los sets con el método train_test_split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
    )

# %% [markdown]
# ## **Normalización o Estandarización (si es necesario)**

# %% [markdown]
# Evalúa la necesidad de normalizar o estandarizar los datos, según los modelos que se aplicarán. Modelos basados en distancia, como KNN, SVM, Regresión Logística y Redes Neuronales, requieren este preprocesamiento. Por otro lado, modelos basados en árboles, como Decision Tree, Random Forest y XGBoost, no son sensibles a la escala de los datos.

# %%
# Graficamos la distribución de los valores de las variables numéricas

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
sns.histplot(data=df, x="ChargesMonthly", kde=True, ax=axes[0])
axes[0].set_title("Distribución de 'ChargesMonthly'")
sns.histplot(data=df, x='Tenure', kde=True, ax=axes[1])
axes[1].set_title("Distribución de 'Tenure'")
plt.tight_layout
plt.show()

# %%
# importar la biblioteca para normalización

from sklearn.preprocessing import MinMaxScaler

# %%
# Aislamos las columnas numéricas

col_numeric = df.select_dtypes(include=["int64", "float64"]).columns
col_numeric
# Out:
# Index(['Tenure', 'ChargesMonthly'], dtype='object')

# %%
# Iniciamos el escalador

scaler = MinMaxScaler()

# Creamos la normalización únicamente en las variables X de entrenamiento y prueba

X_train_norm = X_train.copy()
X_test_norm = X_test.copy()

# Normalización para cada conjunto de entrenamiento y prueba normalizado

X_train_norm[col_numeric] = scaler.fit_transform(X_train[col_numeric])
X_test_norm[col_numeric] = scaler.transform(X_test[col_numeric])

# Chequeo de seguridad con X entrenamiento normalizado

X_train_norm[col_numeric].describe()
# Out:
#             Tenure  ChargesMonthly
# count  5634.000000     5634.000000
# mean      0.449301        0.464700
# std       0.341426        0.299184
# min       0.000000        0.000000
# 25%       0.125000        0.198430
# 50%       0.402778        0.519432
# 75%       0.763889        0.712506
# max       1.000000        1.000000

# %% [markdown]
# ## **Encoding**

# %% [markdown]
# Transforma las variables categóricas a formato numérico para hacerlas compatibles con los algoritmos de machine learning. Utiliza un método de codificación adecuado, como one-hot encoding.
#
# 🔎 Sugerencia:
# Puedes consultar este artículo para entender mejor cuándo usar get_dummies o OneHotEncoder:
# Artículo en Alura sobre codificación categórica

# %%
# Aplicar One-Hot Encoding en datos de entrenamiento

X_train = pd.get_dummies(X_train, drop_first=True)
X_train_norm = pd.get_dummies(X_train_norm, drop_first=True)

# Aplicar en datos de prueba

X_test = pd.get_dummies(X_test, drop_first=True)
X_test_norm = pd.get_dummies(X_test_norm, drop_first=True)

# Asegurar que entrenamiento y prueba tengan las mismas columnas

X_train, X_test = X_train.align(X_test, join='left', axis=1, fill_value=0)
X_train_norm, X_test_norm = X_train_norm.align(X_test_norm, join='left', axis=1, fill_value=0)

X_train.head()
# Out:
#       Tenure  ChargesMonthly  SeniorCitizen_Yes  Partner_Yes  Dependents_Yes  \
# 3793      60           94.10              False         True           False
# 3192      12           19.35              False        False            True
# 4922       2           80.45              False        False           False
# 3926      33           74.75              False         True            True
# 3859      14           86.00              False        False            True
#
#       MultipleLines_Yes  InternetService_Fiber optic  InternetService_No  \
# 3793               True                         True               False
# 3192              False                        False                True
# 4922              False                         True               False
# 3926              False                        False               False
# 3859               True                         True               False
#
# ...

# %%
# Pequeño código para asegurar consistencias

print(X_train.shape)
print(X_train_norm.shape)
# Out:
# (5634, 20)
# (5634, 20)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5634 entries, 3793 to 5679
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Tenure                                 5634 non-null   int64
#  1   ChargesMonthly                         5634 non-null   float64
#  2   SeniorCitizen_Yes                      5634 non-null   bool
#  3   Partner_Yes                            5634 non-null   bool
#  4   Dependents_Yes                         5634 non-null   bool
#  5   MultipleLines_Yes                      5634 non-null   bool
#  6   InternetService_Fiber optic            5634 non-null   bool
#  7   InternetService_No                     5634 non-null   bool
#  8   OnlineSecurity_Yes                     5634 non-null   bool
#  9   OnlineBackup_Yes                       5634 non-null   bool
#  10  DeviceProtection_Yes                   5634 non-null   bool
# ...

# %% [markdown]
# ## **Verificación de la Proporción de Cancelación (Churn)**

# %% [markdown]
# Calcula la proporción de clientes que cancelaron en relación con los que permanecieron activos. Evalúa si existe un desbalance entre las clases, ya que esto puede impactar en los modelos predictivos y en el análisis de los resultados.
#
# 🔎 Sugerencia:
# Puedes usar value_counts() de pandas para obtener esta proporción:
# Documentación oficial de value_counts()

# %%
resumen_balance = (y_train.value_counts(normalize=True) * 100).to_frame(name='Proporción (%)')
display(resumen_balance.style.format("{:.2f}%"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_4d94c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d94c_level0_col0" class="col_heading level0 col0" >Proporción (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Churn</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d94c_level0_row0" class="row_heading level0 row0" >No</th>
#       <td id="T_4d94c_row0_col0" class="data row0 col0" >73.46%</td>
#     </tr>
#     <tr>
#       <th id="T_4d94c_level0_row1" class="row_heading level0 row1" >Yes</th>
#       <td id="T_4d94c_row1_col0" class="data row1 col0" >26.54%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Graficamos el conteo de clases

sns.countplot(x=y_train)
plt.title('Distribución de la Variable Objetivo (Churn)')
plt.xticks([0, 1], ['Permanecen (0)', 'Cancelan (1)'])
plt.show()

# %% [markdown]
# El dataset posee un desbalance moderado. En términos de datos, nuestros dataset generará un modelo que verá 3 veces más ejemplos de "No" que de "Yes". Esto es problemático porque necesitamos enfocarnos en los clientes que sí se fugan (los Churn = "Yes").

# %% [markdown]
# ## **Balanceo de Clases (opcional)**

# %% [markdown]
# Si deseas profundizar en el análisis, aplica técnicas de balanceo como undersampling o oversampling. En situaciones de fuerte desbalanceo, herramientas como SMOTE pueden ser útiles para generar ejemplos sintéticos de la clase minoritaria.
#
# 🔎 Sugerencia:
# Puedes leer más sobre cómo manejar el desbalanceo de clases en este artículo:
# Artículo en Alura sobre desbalanceo de datos

# %% [markdown]
# RESPUESTA: Dado que el set de datos tiene un desbalance moderado, optaremos en esta oportunidad por no persistir en una técnica de balanceo completa. Lo que sí haremos es utilizar el parámetro "class_weight=balanced".

# %% [markdown]
# # **🎯 Correlación y Selección de Variables**

# %% [markdown]
# ## **Análisis de Correlación**

# %% [markdown]
# Visualiza la matriz de correlación para identificar relaciones entre las variables numéricas. Presta especial atención a las variables que muestran una mayor correlación con la cancelación, ya que estas pueden ser fuertes candidatas para el modelo predictivo.

# %%
# Unimos temporalmente para la foto

temp_df = X_train.copy()
temp_df['Churn'] = y_train.map({'Yes': 1, 'No': 0})

# Calculamos correlaciones

plt.figure(figsize=(12, 8))
correlation = temp_df.corr()

# Graficamos solo la relación con 'Churn' para no marearnos

correlation['Churn'].sort_values(ascending=False).plot(kind='bar')
plt.title("Correlación de las variables con el Churn")
plt.show()

# %%
correlation['Churn']
# Out:
# Tenure                                  -0.351948
# ChargesMonthly                           0.188884
# SeniorCitizen_Yes                        0.153134
# Partner_Yes                             -0.152032
# Dependents_Yes                          -0.158042
# MultipleLines_Yes                        0.042973
# InternetService_Fiber optic              0.303902
# InternetService_No                      -0.225631
# OnlineSecurity_Yes                      -0.168577
# OnlineBackup_Yes                        -0.086360
# DeviceProtection_Yes                    -0.067663
# TechSupport_Yes                         -0.171160
# StreamingTV_Yes                          0.067602
# StreamingMovies_Yes                      0.051428
# Contract_One year                       -0.180497
# Contract_Two year                       -0.302556
# PaperlessBilling_Yes                     0.192693
# PaymentMethod_Credit card (automatic)   -0.129420
# PaymentMethod_Electronic check           0.304426
# ...

# %% [markdown]
# ## **Análisis Dirigido**

# %% [markdown]
# Investiga cómo variables específicas se relacionan con la cancelación, tales como:
#
# - **Tiempo de contrato × Cancelación**
# - **Gasto total × Cancelación**
#
# Utiliza gráficos como **boxplots** o **scatter plots** para visualizar patrones y posibles tendencias.

# %%
# Configuramos el espacio para los dos gráficos (Boxplots)

plt.figure(figsize=(15, 6))

# 1. Tiempo de Contrato (Tenure) vs Churn

plt.subplot(1, 2, 1)
sns.boxplot(x='Churn', y='Tenure', data=temp_df, palette='viridis')
plt.title('Antigüedad vs Cancelación')
plt.xlabel('Churn (0=No, 1=Sí)')
plt.ylabel('Meses de Antigüedad (Tenure)')

# 2. Gasto Mensual (ChargesMonthly) vs Churn

plt.subplot(1, 2, 2)
sns.boxplot(x='Churn', y='ChargesMonthly', data=temp_df, palette='magma')
plt.title('Gasto Mensual vs Cancelación')
plt.xlabel('Churn (0=No, 1=Sí)')
plt.ylabel('Gasto Mensual')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_492/2069165066.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='Tenure', data=temp_df, palette='viridis')
# /tmp/ipykernel_492/2069165066.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='ChargesMonthly', data=temp_df, palette='magma')

# %%
temp_df[temp_df['Churn']==1].describe()
# Out:
#             Tenure  ChargesMonthly   Churn
# count  1495.000000     1495.000000  1495.0
# mean     17.955184       74.467659     1.0
# std      19.536154       24.518907     0.0
# min       1.000000       18.850000     1.0
# 25%       2.000000       56.675000     1.0
# 50%      10.000000       79.600000     1.0
# 75%      29.000000       94.200000     1.0
# max      72.000000      118.350000     1.0

# %% [markdown]
# Respecto de la antigüedad (Tenure), vemos que la fuga es temprana, concentrada en los primeros meses. La mediana está 10 meses, esto quiere decir que la mitad de la gente que cancela lo hace antes de cumplir un año. Los clientes nuevos son de "alto riesgo". Si sobreviven los primeros 20 meses, es mucho más probable que se queden para siempre.
#
# Respecto del cargo mensual (ChargesMonthly), vemos que el precio es determinante. El boxplot de Churn = 1 está desplazado hacia arriba, esto es, mayor cargo mensual. La mediana de los que cancelan está en 79.6, mientras que los que no cancelan tienen una mediana de aprox. 65. Los clientes que pagan más por mes tienen una tendencia mayor a irse. Esto sugiere que el Churn podría estar motivado por el precio o por no percibir suficiente valor por lo que pagan.

# %% [markdown]
# # **🤖 Modelado Predictivo**

# %% [markdown]
# ## **Separación de Datos**

# %% [markdown]
# Divide el conjunto de datos en **entrenamiento** y **prueba** para evaluar el rendimiento del modelo. Una división común es **70% para entrenamiento** y **30% para prueba**, o **80/20**, dependiendo del tamaño de la base de datos.

# %% [markdown]
# Esto ya fue hecho en secciones anteriores. Adicionalmente, tenemos 2 conjuntos de datos para X
#
# 1.   X_train y X_test sin normalización
# 2.   X_train y X_test con los valores de Tenure y ChargesMonthly normalizados
#
# Esto nos permitirá trabajar los modelos con los sets de entrenamiento ideales.

# %% [markdown]
# ## **Creación de Modelos**

# %% [markdown]
# Crea al menos dos modelos diferentes para predecir la cancelación de clientes.
#
# - Un modelo puede requerir normalización, como **Regresión Logística** o **KNN**.
# - El otro modelo puede no requerir normalización, como **Árbol de Decisión** o **Random Forest**.
#
# 💡 La decisión de aplicar o no la normalización depende de los modelos seleccionados. Ambos modelos pueden ser creados sin normalización, pero también es una opción combinar modelos con y sin normalización.
#
# **Justificación:**
#
# - **Regresión Logística / KNN:** Estos modelos son sensibles a la escala de los datos, por lo que la normalización es importante para que los coeficientes o las distancias se calculen correctamente.
# - **Árbol de Decisión / Random Forest:** Estos modelos no dependen de la escala de los datos, por lo que no es necesario aplicar normalización.
#
# Si decides normalizar los datos, deberías explicar cómo esta etapa asegura que los modelos basados en distancia o en optimización de parámetros no se vean sesgados por la magnitud de las variables.

# %% [markdown]
# ### Modelo 1: Regresión Logísitca

# %%
# importamos la biblioteca para el modelo, y también las bibliotecas para los reportes, matriz de confusión y puntaje de precisión.

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# Instanciar el modelo

log_model = LogisticRegression(max_iter=1000)

# Entrenar el modelo con los datos NORMALIZADOS

log_model.fit(X_train_norm, y_train)

# Realizar las predicciones con los datos NORMALIZADOS

y_pred_log_norm = log_model.predict(X_test_norm)

# Evaluación

print("--- REGRESIÓN LOGÍSTICA (Datos Normalizados) ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred_log_norm):.4f}")
print("\nMatriz de Confusión:")
print(confusion_matrix(y_test, y_pred_log_norm))
print("\nReporte de Clasificación:")
print(classification_report(y_test, y_pred_log_norm))
# Out:
# --- REGRESIÓN LOGÍSTICA (Datos Normalizados) ---
# Accuracy: 0.7949
#
# Matriz de Confusión:
# [[926 109]
#  [180 194]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#           No       0.84      0.89      0.87      1035
#          Yes       0.64      0.52      0.57       374
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.71      0.72      1409
# weighted avg       0.78      0.79      0.79      1409

# %% [markdown]
# Modelo de Regresión Logísitca Balanceado

# %%
# Instanciamos con balanceo de clases simple (class_weight)

log_model_balanced = LogisticRegression(max_iter=1000, class_weight='balanced')

# Entrenamos con los mismos datos NORMALIZADOS

log_model_balanced.fit(X_train_norm, y_train)

# Predicciones con los datos NORMALIZADOS

y_pred_log_bal = log_model_balanced.predict(X_test_norm)

# Evaluación

print("--- REGRESIÓN LOGÍSTICA BALANCEADA ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred_log_bal):.4f}")
print("\nMatriz de Confusión:")
print(confusion_matrix(y_test, y_pred_log_bal))
print("\nReporte de Clasificación:")
print(classification_report(y_test, y_pred_log_bal))
# Out:
# --- REGRESIÓN LOGÍSTICA BALANCEADA ---
# Accuracy: 0.7445
#
# Matriz de Confusión:
# [[753 282]
#  [ 78 296]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#           No       0.91      0.73      0.81      1035
#          Yes       0.51      0.79      0.62       374
#
#     accuracy                           0.74      1409
#    macro avg       0.71      0.76      0.71      1409
# weighted avg       0.80      0.74      0.76      1409

# %% [markdown]
# ### Modelo 2: K-Nearest Neighbors (KNN)

# %%
# Llamamos a la biblioteca para poder importar el modelo

from sklearn.neighbors import KNeighborsClassifier

# %%
# Instanciar (probaremos con 5 vecinos por defecto)

knn_model = KNeighborsClassifier(n_neighbors=5)

# Entrenar con los datos NORMALIZADOS

knn_model.fit(X_train_norm, y_train)

# Predicciones

y_pred_knn = knn_model.predict(X_test_norm)

# Evaluación

print("--- KNN (Datos Normalizados) ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred_knn):.4f}")
print("\nMatriz de Confusión:")
print(confusion_matrix(y_test, y_pred_knn))
print("\nReporte de Clasificación:")
print(classification_report(y_test, y_pred_knn))
# Out:
# --- KNN (Datos Normalizados) ---
# Accuracy: 0.7594
#
# Matriz de Confusión:
# [[890 145]
#  [194 180]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#           No       0.82      0.86      0.84      1035
#          Yes       0.55      0.48      0.52       374
#
#     accuracy                           0.76      1409
#    macro avg       0.69      0.67      0.68      1409
# weighted avg       0.75      0.76      0.75      1409

# %% [markdown]
# ### Modelo 3: Árbol de Decisión

# %%
# Llamamos a la biblioteca para poder importar el modelo

from sklearn.tree import DecisionTreeClassifier

# %%
# Instanciar (profundidad máxima de 5 para evitar problemas de memorizar set)

tree_model = DecisionTreeClassifier(max_depth=5, random_state=42)

# Entrenar con los datos ORIGINALES

tree_model.fit(X_train, y_train)

# Predicciones

y_pred_tree = tree_model.predict(X_test)

# Evaluación

print("--- ÁRBOL DE DECISIÓN (Datos Originales) ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred_tree):.4f}")
print("\nMatriz de Confusión:")
print(confusion_matrix(y_test, y_pred_tree))
print("\nReporte de Clasificación:")
print(classification_report(y_test, y_pred_tree))
# Out:
# --- ÁRBOL DE DECISIÓN (Datos Originales) ---
# Accuracy: 0.7842
#
# Matriz de Confusión:
# [[884 151]
#  [153 221]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#           No       0.85      0.85      0.85      1035
#          Yes       0.59      0.59      0.59       374
#
#     accuracy                           0.78      1409
#    macro avg       0.72      0.72      0.72      1409
# weighted avg       0.78      0.78      0.78      1409

# %% [markdown]
# ### Modelo 4: Random Forest

# %%
# Llamamos a la biblioteca para poder importar el modelo

from sklearn.ensemble import RandomForestClassifier

# %%
# Instanciar (usaremos 100 árboles y equilibrio de peso automático)
# El parámetro class_weight='balanced' ayudará con el desbalance que medimos antes

rf_model = RandomForestClassifier(n_estimators=100, max_depth=10, class_weight='balanced', random_state=42)

# Entrenar con los datos ORIGINALES

rf_model.fit(X_train, y_train)

# Predicciones

y_pred_rf = rf_model.predict(X_test)

# Evaluación

print("--- RANDOM FOREST (Datos Originales) ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred_rf):.4f}")
print("\nMatriz de Confusión:")
print(confusion_matrix(y_test, y_pred_rf))
print("\nReporte de Clasificación:")
print(classification_report(y_test, y_pred_rf))
# Out:
# --- RANDOM FOREST (Datos Originales) ---
# Accuracy: 0.7764
#
# Matriz de Confusión:
# [[816 219]
#  [ 96 278]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#           No       0.89      0.79      0.84      1035
#          Yes       0.56      0.74      0.64       374
#
#     accuracy                           0.78      1409
#    macro avg       0.73      0.77      0.74      1409
# weighted avg       0.81      0.78      0.79      1409

# %% [markdown]
# # **📋 Interpretación y Conclusiones**

# %% [markdown]
# ## **Análisis de la Importancia de las Variables**

# %% [markdown]
# Después de elegir los modelos, realiza el análisis de las variables más relevantes para la predicción de la cancelación:
#
# - **Regresión Logística**: Investiga los coeficientes de las variables, que muestran su contribución a la predicción de cancelación.
# - **KNN (K-Nearest Neighbors)**: Observa cómo los vecinos más cercanos influyen en la decisión de clasificación. Las variables más impactantes pueden ser aquellas que más contribuyen a la proximidad entre los puntos de datos.
# - **Random Forest**: Utiliza la importancia de las variables proporcionada por el modelo. Random Forest calcula la importancia basándose en cómo cada variable contribuye a la reducción de la impureza durante las divisiones de los árboles.
# - **SVM (Support Vector Machine)**: En el SVM, las variables más relevantes son aquellas que influyen en la frontera de decisión entre las clases. Puedes analizar los coeficientes de los vectores de soporte para entender qué variables tienen mayor impacto.
# - **Otros Modelos**: Dependiendo del modelo elegido, considera el análisis de métricas específicas para comprender la relevancia de las variables. Por ejemplo, coeficientes en modelos lineales, pesos en redes neuronales, o la importancia relativa en técnicas de boosting (como XGBoost).

# %% [markdown]
# Vamos a seleccionar solamente al modelo de Regresión Logística Balanceado y al modelo de Random Forest balanceado.

# %%
# Importancia en Random Forest

rf_importances = pd.DataFrame({
    'Variable': X_train.columns,
    'Importancia': rf_model.feature_importances_
}).sort_values(by='Importancia', ascending=False)

# Coeficientes en Regresión Logística (usamos el absoluto para ver impacto total)

log_coeffs = pd.DataFrame({
    'Variable': X_train.columns,
    'Impacto': log_model_balanced.coef_[0]
}).sort_values(by='Impacto', ascending=False)

# Graficamos

fig, ax = plt.subplots(1, 2, figsize=(16, 6))

sns.barplot(x='Importancia', y='Variable', data=rf_importances.head(5), ax=ax[0], palette='magma')
ax[0].set_title('Top 5: Importancia en Random Forest')

sns.barplot(x='Impacto', y='Variable', data=log_coeffs.head(5), ax=ax[1], palette='coolwarm')
ax[1].set_title('Top 5: Coeficientes Positivos (Riesgo) en Logística')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_492/2198122896.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importancia', y='Variable', data=rf_importances.head(5), ax=ax[0], palette='magma')
# /tmp/ipykernel_492/2198122896.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Impacto', y='Variable', data=log_coeffs.head(5), ax=ax[1], palette='coolwarm')

# %% [markdown]
# ## **Conclusión**

# %% [markdown]
# Elaboren un informe detallado, destacando los factores que más influyen en la cancelación, basándose en las variables seleccionadas y en el rendimiento de cada modelo.
#
# Identifiquen los **principales factores** que afectan la cancelación de clientes y propongan estrategias de retención basadas en los resultados obtenidos.

# %% [markdown]
# ### Informe de Análisis de Retención: Factores Críticos de Churn

# %% [markdown]
# #### 1. Resumen del Rendimiento de los Modelos
#
# Para este análisis se evaluaron cuatro modelos:
#
# * Regresión Logística (con y sin Balanceo)
# * KNN
# * Árbol de decisión
# * Random Forest (Balanceado)
#
# Los modelos elegidos para el análisis final fueron **Random Forest (Balanceado)** y la **Regresión Logística (Balanceada)**, que fueron los más efectivos para los objetivos de negocio.
#
# * **Modelo Recomendado:** Random Forest
# * Aunque la Regresión Logística mostró un Recall ligeramente superior (79%), el Random Forest ofreció un mejor equilibrio (F1-score: 0.64) y una mayor precisión (56%), lo que permite identificar a los clientes en riesgo reduciendo el costo de campañas innecesarias hacia clientes que no pensaban irse.

# %% [markdown]
# #### 2. Principales Factores de Cancelación
#
# Basándonos en la importancia de variables del Random Forest y los coeficientes de la Regresión Logística, identificamos tres pilares que disparan el Churn:
#
# 1. **Fragilidad en Clientes Nuevos (Tenure):** La antigüedad es el predictor más fuerte. Existe una "zona de alto riesgo" en los primeros 12 meses donde la probabilidad de fuga es máxima.
# 2. **El "Efecto Fibra Óptica":** Los clientes con servicio de Fibra Óptica tienen un riesgo significativamente mayor de cancelar en comparación con los de DSL. Esto sugiere una posible desconexión entre el precio, la expectativa y la realidad del servicio entregado.
# 3. **Métodos de Pago y Contratos:** Los contratos con cargo mensual y el uso de Cheque Electrónico son facilitadores de la fuga. Los clientes con estos perfiles no tienen barreras de salida ni incentivos de permanencia, por lo que se les hace muy fácil cancelar.

# %% [markdown]
# #### 3. Estrategias de Retención Propuestas
#
# Se sugieren las siguientes acciones estratégicas:
#
# * **Programa de acompañamiento para nuevos clientes "Kit de Bienvenida":** Implementar seguimiento frecuente durante los primeros 6 meses de contrato, ofreciendo soporte técnico proactivo, encuestas de satisfacción e información sobre el servicio contratado.
# * **Revisión del Servicio de Fibra Óptica:** Investigar la causa técnica o comercial del Churn por este servicio. Si es por precio, crear planes de fidelización; si es técnico, reforzar el soporte y evaluar el estado de la tecnología vs la competencia.
# * **Incentivos para pasarse a un modelo anual o bianual:** Ofrecer descuentos y/o beneficios exclusivos (como streaming gratis, por ejemplo) a clientes que solo tiene el servicio de modalidad mensual.
# * **Promoción de Pago Automático (PAD o PAC):** Incentivar el cambio de Cheque Electrónico a Tarjeta de Crédito o Transferencia Automática, ofreciendo un detalle de bajo costo como un día de streaming gratis o un pequeño descuento en la siguiente boleta, ya que estos métodos suelen generar una relación más estable y duradera.

# %% [markdown]
# #### 4. Conclusión
#
# La diferencia principal entre modelos (Tenure en RF vs. Fibra en Logística) nos confirma que el Churn es un fenómeno que se atribuye a múltiples causas, por lo que no puede ser observado como un fenómeno aislado: mientras que el tiempo de permanencia define la estructura de la lealtad, el tipo de servicio (Fibra) actúa como el detonante principal de la insatisfacción actual.
